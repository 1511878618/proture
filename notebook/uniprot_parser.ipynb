# %% [markdown]
# # UniProt Parser
#
# 从UniProt上检索并下载包含Ensemble在内的所有感兴趣的UniProt数据，获取对应UniProt Accession对应的RefSeq ID，存在一对多的情况

# %%
import re 
from typing import Any, List
import pandas as pd  
import sys
from proture.download.utils import download_url
from proture.utils import explode
from functools import reduce
pd.set_option('display.max_columns', 100)

def parse_alternative_text(text:str):
    if pd.isna(text):
        return "default"
    else:
        pattern1 = r"Name=.*Displayed"
        search_result = re.search(pattern1, text)
        if search_result:
            iso_text = search_result.group()
            pattern2 = r"(?<=IsoId=).*(?=;)"
            search_result_2 = re.search(pattern2, iso_text)
            if search_result_2: 
                return search_result_2.group()
            else:
                return "default"
        else:
            return "default"
        
def dict_RefSeq(x:str):
    if pd.isna(x):
        return {"default":[]}
    else:
        re_sep=r"(?<=]);"
        is_isinstance_sep = re.search(r"(?<=]);", x)
        if is_isinstance_sep:
            isoform_RefSeq_mapping_dict = {}
            isoform_mapping:List[str] = re.split(r"(?<=]);", x)
            for isoform in isoform_mapping:
                if isoform != "":
                    split_isoform = isoform.split(" ")
                    if len(isoform.split(" ")) >=2:
                        canonical, isoform_id = isoform.split(" ")
                    else:
                        canonical = isoform.strip(";")
                        isoform_id = "default"
                    isoform_id = isoform_id.strip("[").strip("]")
                    canonical = canonical.split(";")
                    
                    if isoform_id not in isoform_RefSeq_mapping_dict.keys():
                        if isinstance(canonical, (list, tuple)):
                            isoform_RefSeq_mapping_dict[isoform_id] = canonical
                        else:
                            raise ValueError(f"{canonical} is not list or tuple, please check")
                    else:
                        if isinstance(canonical, (list, tuple)):
                            isoform_RefSeq_mapping_dict[isoform_id] += canonical

        
            return isoform_RefSeq_mapping_dict

        else:
            return {"default":[i.strip("[").strip("]") for i in x.split(";") if i != ""]}

def load_LRG_RefSeqGene(local_dir:str = None, save_dir:str = "./LRG_RefSeqGene"):
    if local_dir is None:
        # see https://ftp.ncbi.nlm.nih.gov/refseq/H_sapiens/RefSeqGene/
        url = "https://ftp.ncbi.nlm.nih.gov/refseq/H_sapiens/RefSeqGene/LRG_RefSeqGene"
        download_url(url = url, output_file = save_dir)
        local_dir = save_dir

    return pd.read_csv(local_dir, index_col=False, sep="\t")

def add_lists(two_dimension_list:List[List[Any]]):
    return reduce(lambda x,y: x + y, two_dimension_list)

# %%
def UniProt2NP(homo_sapians_uniprot_df:pd.DataFrame, contain_all_uniprot_isoform:bool = False):
    """UniProt Accession mapping to RefSeq Nucletide by LRG, see more at UniProt and LRG:https://ftp.ncbi.nlm.nih.gov/refseq/H_sapiens/RefSeqGene/

    Args:
        homo_sapians_uniprot_df (pd.DataFrame): each row are UniProt Accession entry and must contain two fields of UniProt download result:1):RefSeq;2)Alternative products (isoforms)
        contain_all_uniprot_isoform (bool, optional): output result will contain all RefSeq associated with each UniProt Accession isoform or just the canonical isoform of this entry, if True, will contain RefSeq only if it really associated with canonical isoform of UniProt Accession entry. Defaults to False.

    Returns:
        _type_: _description_
    """
    homo_sapians_uniprot_df = pd.read_csv(homo_sapians_uniprot_dir, index_col=False, sep="\t")

    # step1 parse the canonical isoforms of UniProt Accession and generate each isoform to RefSeq mapping 
    homo_sapians_uniprot_df["canonical isoforms"] = homo_sapians_uniprot_df["Alternative products (isoforms)"].apply(lambda x: parse_alternative_text(x))
    homo_sapians_uniprot_df["canonical RefSeq"] = homo_sapians_uniprot_df["RefSeq"].apply(lambda x: dict_RefSeq(x))

    # step2 get canonical or all isoform of UniProt Accession to associated RefSeq 
    def map2canonical(x):
        return pd.Series({"canonical protein ID":x["canonical RefSeq"].get(x["canonical isoforms"], None)})
        
    if not contain_all_uniprot_isoform:
        homo_sapians_uniprot_df["canonical RefSeq protein"] = homo_sapians_uniprot_df.loc[:, ["canonical RefSeq", "canonical isoforms"]].apply(lambda x: map2canonical(x), axis=1)
    else:
        homo_sapians_uniprot_df["canonical RefSeq protein"] = homo_sapians_uniprot_df["canonical RefSeq"].apply(lambda x: add_lists(list(x.values())))

    del homo_sapians_uniprot_df["canonical isoforms"]
    del homo_sapians_uniprot_df["canonical RefSeq"]
    # step3 explode multi-mapping relationship among canonical UniProt Accession and RefSeq to multi-row.
    homo_sapians_uniprot_df = homo_sapians_uniprot_df.explode("canonical RefSeq protein")

    # step 4 Convert NP to NM by LRG_RefSeqGene file
    LRG_RefSeqGene = load_LRG_RefSeqGene(local_dir = "/p300s/wangmx_group/xutingfeng/statistic/proture/data/RefSeq/LRG_RefSeqGene")
    NM2NP_mapping = LRG_RefSeqGene.loc[:, ["RNA", "Protein"]].drop_duplicates().dropna(how="any")

    hsapians_uniprot_NM = pd.merge(left = homo_sapians_uniprot_df.dropna(subset=["canonical RefSeq protein"], axis=0), right = NM2NP_mapping, left_on="canonical RefSeq protein", right_on= "Protein", how="inner")


    print(f'now have gene:{len(explode(hsapians_uniprot_NM, column="Gene Names", sep =";")["Gene Names"].unique())} in the dataset')
    return hsapians_uniprot_NM

# %%
homo_sapians_uniprot_dir = "/p300s/wangmx_group/xutingfeng/statistic/proture/data/UniProt/uniprot_homo_sapians.tsv"  # this file is query from UniProt with fields Ensemble
homo_sapians_uniprot_df = pd.read_csv(homo_sapians_uniprot_dir, index_col=False, sep="\t")

# %%
UniProt2NP(homo_sapians_uniprot_df = homo_sapians_uniprot_df, column = "Alternative products (isoforms)", contain_all_uniprot_isoform=True)
# Out:
# now have gene:3105 in the dataset
#         From   Entry  Reviewed   Entry Name  \
# 0     Q99933  Q99933  reviewed   BAG1_HUMAN
# 1     Q9NZK5  Q9NZK5  reviewed   ADA2_HUMAN
# 2     Q9NZK5  Q9NZK5  reviewed   ADA2_HUMAN
# 3     Q9NZK5  Q9NZK5  reviewed   ADA2_HUMAN
# 4     Q9NZK5  Q9NZK5  reviewed   ADA2_HUMAN
# ...      ...     ...       ...          ...
# 8754  Q9NXR8  Q9NXR8  reviewed   ING3_HUMAN
# 8755  Q9NXR8  Q9NXR8  reviewed   ING3_HUMAN
# 8756  Q9HBX9  Q9HBX9  reviewed  RXFP1_HUMAN
# 8757  Q9HBX9  Q9HBX9  reviewed  RXFP1_HUMAN
# 8758  Q9HBX9  Q9HBX9  reviewed  RXFP1_HUMAN
#
#                                           Protein names  \
# 0     BAG family molecular chaperone regulator 1 (BA...
# 1     Adenosine deaminase 2 (EC 3.5.4.4) (Cat eye sy...
# 2     Adenosine deaminase 2 (EC 3.5.4.4) (Cat eye sy...
# 3     Adenosine deaminase 2 (EC 3.5.4.4) (Cat eye sy...
# 4     Adenosine deaminase 2 (EC 3.5.4.4) (Cat eye sy...
# ...                                                 ...
# 8754            Inhibitor of growth protein 3 (p47ING3)
# 8755            Inhibitor of growth protein 3 (p47ING3)
# 8756  Relaxin receptor 1 (Leucine-rich repeat-contai...
# 8757  Relaxin receptor 1 (Leucine-rich repeat-contai...
# 8758  Relaxin receptor 1 (Leucine-rich repeat-contai...
#
#                  Gene Names  \
# 0                  BAG1 HAP
# 1     ADA2 ADGF CECR1 IDGFL
# 2     ADA2 ADGF CECR1 IDGFL
# 3     ADA2 ADGF CECR1 IDGFL
# 4     ADA2 ADGF CECR1 IDGFL
# ...                     ...
# 8754           ING3 HSPC301
# 8755           ING3 HSPC301
# 8756             RXFP1 LGR7
# 8757             RXFP1 LGR7
# 8758             RXFP1 LGR7
#
#                                                  RefSeq  \
# 0     NP_001165886.1 [Q99933-4];NP_004314.5 [Q99933-1];
# 1     NP_001269154.1 [Q9NZK5-1];NP_001269155.1 [Q9NZ...
# 2     NP_001269154.1 [Q9NZK5-1];NP_001269155.1 [Q9NZ...
# 3     NP_001269154.1 [Q9NZK5-1];NP_001269155.1 [Q9NZ...
# 4     NP_001269154.1 [Q9NZK5-1];NP_001269155.1 [Q9NZ...
# ...                                                 ...
# 8754     NP_061944.2 [Q9NXR8-1];NP_938008.1 [Q9NXR8-2];
# 8755     NP_061944.2 [Q9NXR8-1];NP_938008.1 [Q9NXR8-2];
# 8756  NP_001240657.1 [Q9HBX9-2];NP_001240658.1 [Q9HB...
# 8757  NP_001240657.1 [Q9HBX9-2];NP_001240658.1 [Q9HB...
# 8758  NP_001240657.1 [Q9HBX9-2];NP_001240658.1 [Q9HB...
#
#                         Alternative products (isoforms)  \
# 0     ALTERNATIVE PRODUCTS:  Event=Alternative splic...
# 1     ALTERNATIVE PRODUCTS:  Event=Alternative splic...
# 2     ALTERNATIVE PRODUCTS:  Event=Alternative splic...
# 3     ALTERNATIVE PRODUCTS:  Event=Alternative splic...
# 4     ALTERNATIVE PRODUCTS:  Event=Alternative splic...
# ...                                                 ...
# 8754  ALTERNATIVE PRODUCTS:  Event=Alternative splic...
# 8755  ALTERNATIVE PRODUCTS:  Event=Alternative splic...
# 8756  ALTERNATIVE PRODUCTS:  Event=Alternative splic...
# 8757  ALTERNATIVE PRODUCTS:  Event=Alternative splic...
# 8758  ALTERNATIVE PRODUCTS:  Event=Alternative splic...
#
#      canonical RefSeq protein             RNA         Protein
# 0              NP_001165886.1  NM_001172415.2  NP_001165886.1
# 1              NP_001269154.1  NM_001282225.2  NP_001269154.1
# 2              NP_001269155.1  NM_001282226.2  NP_001269155.1
# 3              NP_001269156.1  NM_001282227.2  NP_001269156.1
# 4              NP_001269157.1  NM_001282228.2  NP_001269157.1
# ...                       ...             ...             ...
# 8754              NP_061944.2     NM_019071.3     NP_061944.2
# 8755              NP_938008.1     NM_198267.2     NP_938008.1
# 8756           NP_001240657.1  NM_001253728.2  NP_001240657.1
# 8757           NP_001240658.1  NM_001253729.2  NP_001240658.1
# 8758              NP_067647.2     NM_021634.4     NP_067647.2
#
# [8759 rows x 11 columns]

# %%
import re 
def splitName2Attribution(x):
    """
    splitName2Attribution HGSV 命名法：https://varnomen.hgvs.org/recommendations/general/
    refSeq:https://en.wikipedia.org/wiki/RefSeq#:~:text=The%20Reference%20Sequence%20(RefSeq)%20database,was%20first%20introduced%20in%202000.

    Args:
        str类型: "NM_017547.4(FOXRED1):c.694C>T (p.Gln232Ter)"

    Returns:
        ["NM_017547.4", "Gln232Ter","694C>T"]
    """
    ref_pattern = r"[A-Za-z]+_[0-9]+[\.]*[0-9]*"
    AAS_pattern = r"(?<=(p.))[A-Za-z]{0,3}[^\s()]*"
    SNP_pattern = r"(?<=(c.))[\d]*[^\s()]*"
    ref = re.search(ref_pattern, x).group() if re.search(ref_pattern, x) else None 
    AAS = re.search(AAS_pattern, x).group() if  re.search(AAS_pattern, x) else None 
    SNP = re.search(SNP_pattern, x).group() if re.search(SNP_pattern, x) else None 
    return ref, AAS, SNP

# %%
clinvar_variant_summary_dir = "/p300s/wangmx_group/xutingfeng/statistic/proture/data/clinvar/variant_summary_2018-02_filtertxt.gz"
clinvar_variant_summary = pd.read_csv(clinvar_variant_summary_dir, sep="\t", compression="gzip")
clinvar_variant_summary.insert(3, "transcript_accession", clinvar_variant_summary["Name"].apply(lambda x: splitName2Attribution(x)[0]))
clinvar_variant_summary
# Out:
#        AlleleID                       Type  \
# 0         15044  single nucleotide variant
# 1         15045  single nucleotide variant
# 2         15051  single nucleotide variant
# 3         15052  single nucleotide variant
# 4         15056  single nucleotide variant
# ...         ...                        ...
# 37299    481081  single nucleotide variant
# 37300    481082  single nucleotide variant
# 37301    481084  single nucleotide variant
# 37302    481124  single nucleotide variant
# 37303    481158  single nucleotide variant
#
#                                                Name transcript_accession  \
# 0       NM_017547.3(FOXRED1):c.694C>T (p.Gln232Ter)          NM_017547.3
# 1      NM_017547.3(FOXRED1):c.1289A>G (p.Asn430Ser)          NM_017547.3
# 2           NM_000410.3(HFE):c.314T>C (p.Ile105Thr)          NM_000410.3
# 3            NM_000410.3(HFE):c.277G>C (p.Gly93Arg)          NM_000410.3
# 4           NM_000410.3(HFE):c.381A>C (p.Gln127His)          NM_000410.3
# ...                                             ...                  ...
# 37299   NM_001110556.1(FLNA):c.853C>T (p.Arg285Cys)       NM_001110556.1
# 37300     NM_001110556.1(FLNA):c.82A>G (p.Met28Val)       NM_001110556.1
# 37301      NM_000049.2(ASPA):c.604G>C (p.Ala202Pro)          NM_000049.2
# 37302   NM_015120.4(ALMS1):c.5146A>T (p.Arg1716Ter)          NM_015120.4
# 37303     NM_024887.3(DHDDS):c.632G>A (p.Arg211Gln)          NM_024887.3
#
#        GeneID GeneSymbol     HGNC_ID ClinicalSignificance  ClinSigSimple  \
# 0       55572    FOXRED1  HGNC:26927           Pathogenic              1
# 1       55572    FOXRED1  HGNC:26927           Pathogenic              1
# 2        3077        HFE   HGNC:4886           Pathogenic              1
# 3        3077        HFE   HGNC:4886           Pathogenic              1
# 4        3077        HFE   HGNC:4886           Pathogenic              1
# ...       ...        ...         ...                  ...            ...
# 37299    2316       FLNA   HGNC:3754           Pathogenic              1
# 37300    2316       FLNA   HGNC:3754           Pathogenic              1
# 37301     443       ASPA    HGNC:756    Likely pathogenic              1
# 37302    7840      ALMS1    HGNC:428    Likely pathogenic              1
# 37303   79947      DHDDS  HGNC:20603           Pathogenic              1
#
#       LastEvaluated  RS# (dbSNP) nsv/esv (dbVar)  RCVaccession  \
# 0      Oct 01, 2010    267606829               -  RCV000000015
# 1      Oct 01, 2010    267606830               -  RCV000000016
# 2      Jun 01, 1999     28934596               -  RCV000000029
# 3      Jun 01, 1999     28934597               -  RCV000000030
# 4      Aug 01, 1999     28934595               -  RCV000000034
# ...             ...          ...             ...           ...
# 37299             -           -1               -  RCV000577903
# 37300             -           -1               -  RCV000577884
# 37301  Sep 28, 2017    147763700               -  RCV000577927
# 37302  Aug 01, 2017    773513360               -  RCV000578023
# 37303  Jan 24, 2018           -1               -  RCV000578123
#
#                                             PhenotypeIDS  \
# 0                            MedGen:C1838979,OMIM:252010
# 1                            MedGen:C1838979,OMIM:252010
# 2                            MedGen:C3469186,OMIM:235200
# 3                            MedGen:C3469186,OMIM:235200
# 4                            MedGen:C3469186,OMIM:235200
# ...                                                  ...
# 37299  MedGen:C1848213,OMIM:300049,OMIM:300537,SNOMED...
# 37300  MedGen:C1848213,OMIM:300049,OMIM:300537,SNOMED...
# 37301  MedGen:C0206307,OMIM:271900,Orphanet:ORPHA141,...
# 37302  MedGen:C0268425,OMIM:203800,Orphanet:ORPHA64,S...
# 37303                        MedGen:CN769090,OMIM:617836
#
#                                            PhenotypeList     Origin  \
# 0                     Mitochondrial complex I deficiency   germline
# 1                     Mitochondrial complex I deficiency   germline
# 2                                 Hemochromatosis type 1   germline
# 3                                 Hemochromatosis type 1   germline
# 4                                 Hemochromatosis type 1   germline
# ...                                                  ...        ...
# 37299              Periventricular nodular heterotopia 1  inherited
# 37300              Periventricular nodular heterotopia 1    de novo
# 37301      Spongy degeneration of central nervous system   germline
# 37302                                   Alstrom syndrome   germline
# 37303  DEVELOPMENTAL DELAY AND SEIZURES WITH OR WITHO...   germline
#
#       OriginSimple Assembly ChromosomeAccession Chromosome      Start  \
# 0         germline   GRCh37         NC_000011.9         11  126145284
# 1         germline   GRCh37         NC_000011.9         11  126147412
# 2         germline   GRCh37        NC_000006.11          6   26091306
# 3         germline   GRCh37        NC_000006.11          6   26091269
# 4         germline   GRCh37        NC_000006.11          6   26091582
# ...            ...      ...                 ...        ...        ...
# 37299     germline   GRCh37        NC_000023.10          X  153595780
# 37300     germline   GRCh37        NC_000023.10          X  153599532
# 37301     germline   GRCh37        NC_000017.10         17    3392606
# 37302     germline   GRCh37        NC_000002.11          2   73678797
# 37303     germline   GRCh37        NC_000001.10          1   26784371
#
#             Stop ReferenceAllele AlternateAllele Cytogenetic  \
# 0      126145284               C               T       11q24
# 1      126147412               A               G       11q24
# 2       26091306               T               C      6p22.2
# 3       26091269               G               C      6p22.2
# 4       26091582               A               C      6p22.2
# ...          ...             ...             ...         ...
# 37299  153595780               G               A        Xq28
# 37300  153599532               T               C        Xq28
# 37301    3392606               G               C     17p13.2
# 37302   73678797               A               T      2p13.1
# 37303   26784371               G               A           -
#
#                               ReviewStatus  NumberSubmitters Guidelines  \
# 0           no assertion criteria provided                 1        NaN
# 1           no assertion criteria provided                 1        NaN
# 2           no assertion criteria provided                 1        NaN
# 3           no assertion criteria provided                 1        NaN
# 4           no assertion criteria provided                 1        NaN
# ...                                    ...               ...        ...
# 37299       no assertion criteria provided                 1        NaN
# 37300       no assertion criteria provided                 1        NaN
# 37301  criteria provided, single submitter                 1        NaN
# 37302  criteria provided, single submitter                 1        NaN
# 37303       no assertion criteria provided                 1        NaN
#
#       TestedInGTR                                           OtherIDs  \
# 0               N                   OMIM Allelic Variant:613622.0001
# 1               N  OMIM Allelic Variant:613622.0002,UniProtKB (pr...
# 2               N  OMIM Allelic Variant:613609.0009,UniProtKB (pr...
# 3               N  OMIM Allelic Variant:613609.0010,UniProtKB (pr...
# 4               N  OMIM Allelic Variant:613609.0007,UniProtKB (pr...
# ...           ...                                                ...
# 37299           N                                                  -
# 37300           N                                                  -
# 37301           N                                                  -
# 37302           N                                                  -
# 37303           N                   OMIM Allelic Variant:608172.0003
#
#        SubmitterCategories
# 0                        1
# 1                        1
# 2                        1
# 3                        1
# 4                        1
# ...                    ...
# 37299                    2
# 37300                    2
# 37301                    2
# 37302                    2
# 37303                    1
#
# [37304 rows x 31 columns]

# %%
clinvar_on_canonical = pd.merge(clinvar_variant_summary, hsapians_uniprot_NM, left_on="transcript_accession", right_on="RNA", how="inner")
clinvar_on_canonical
# Out:
#        AlleleID                       Type  \
# 0         15156  single nucleotide variant
# 1         15157  single nucleotide variant
# 2         15159  single nucleotide variant
# 3         15160  single nucleotide variant
# 4         15162  single nucleotide variant
# ...         ...                        ...
# 10269    432279  single nucleotide variant
# 10270    437833  single nucleotide variant
# 10271    437890  single nucleotide variant
# 10272    438464  single nucleotide variant
# 10273    446587  single nucleotide variant
#
#                                              Name transcript_accession  \
# 0         NM_000071.2(CBS):c.919G>A (p.Gly307Ser)          NM_000071.2
# 1         NM_000071.2(CBS):c.434C>T (p.Pro145Leu)          NM_000071.2
# 2         NM_000071.2(CBS):c.833T>C (p.Ile278Thr)          NM_000071.2
# 3         NM_000071.2(CBS):c.415G>A (p.Gly139Arg)          NM_000071.2
# 4        NM_000071.2(CBS):c.1150A>G (p.Lys384Glu)          NM_000071.2
# ...                                           ...                  ...
# 10269    NM_002389.4(CD46):c.685C>T (p.Arg229Ter)          NM_002389.4
# 10270   NM_002389.4(CD46):c.1148C>T (p.Thr383Ile)          NM_002389.4
# 10271    NM_001198551.1(WT1):c.48C>A (p.Tyr16Ter)       NM_001198551.1
# 10272       NM_013995.2(LAMP2):c.1A>T (p.Met1Leu)          NM_013995.2
# 10273  NM_001042351.2(G6PD):c.209A>G (p.Tyr70Cys)       NM_001042351.2
#
#        GeneID GeneSymbol     HGNC_ID ClinicalSignificance  ClinSigSimple  \
# 0         875        CBS   HGNC:1550           Pathogenic              1
# 1         875        CBS   HGNC:1550           Pathogenic              1
# 2         875        CBS   HGNC:1550           Pathogenic              1
# 3         875        CBS   HGNC:1550           Pathogenic              1
# 4         875        CBS   HGNC:1550           Pathogenic              1
# ...       ...        ...         ...                  ...            ...
# 10269    4179       CD46   HGNC:6953    Likely pathogenic              1
# 10270    4179       CD46   HGNC:6953    Likely pathogenic              1
# 10271    7490        WT1  HGNC:12796    Likely pathogenic              1
# 10272    3920      LAMP2   HGNC:6501    Likely pathogenic              1
# 10273    2539       G6PD   HGNC:4057    Likely pathogenic              1
#
#       LastEvaluated  RS# (dbSNP) nsv/esv (dbVar)  \
# 0      Jul 19, 2017    121964962               -
# 1      Jun 01, 1993    121964963               -
# 2      Oct 31, 2017      5742905               -
# 3      Jul 01, 1995    121964965               -
# 4      Jan 01, 1997    121964967               -
# ...             ...          ...             ...
# 10269  Apr 20, 2017           -1               -
# 10270  Feb 28, 2017    146803767               -
# 10271  Jun 30, 2017           -1               -
# 10272  Mar 31, 2017           -1               -
# 10273  Oct 13, 2017    782090947               -
#
#                                             RCVaccession  \
# 0      RCV000000138;RCV000366433;RCV000173641;RCV0000...
# 1                                           RCV000000139
# 2      RCV000000142;RCV000379069;RCV000173640;RCV0000...
# 3                                           RCV000000143
# 4                                           RCV000000145
# ...                                                  ...
# 10269                                       RCV000505668
# 10270                                       RCV000513625
# 10271                                       RCV000512713
# 10272                                       RCV000512988
# 10273                                       RCV000521290
#
#                                             PhenotypeIDS  \
# 0      na;MedGen:C0019880;MedGen:C3150344,OMIM:236200...
# 1                                        MedGen:CN068394
# 2      na;MedGen:C0019880;MedGen:C3150344,OMIM:236200...
# 3                                        MedGen:CN068394
# 4                                        MedGen:CN068394
# ...                                                  ...
# 10269    MedGen:C2752040,OMIM:612922,Orphanet:ORPHA93576
# 10270                                    MedGen:CN517202
# 10271                                    MedGen:CN517202
# 10272                                    MedGen:CN517202
# 10273                                    MedGen:CN517202
#
#                                            PhenotypeList            Origin  \
# 0      HYPERHOMOCYSTEINEMIA, THROMBOTIC, CBS-RELATED;...  germline;unknown
# 1                  Homocystinuria, pyridoxine-responsive          germline
# 2      HYPERHOMOCYSTEINEMIA, THROMBOTIC, CBS-RELATED;...  germline;unknown
# 3                  Homocystinuria, pyridoxine-responsive          germline
# 4                  Homocystinuria, pyridoxine-responsive          germline
# ...                                                  ...               ...
# 10269               Atypical hemolytic-uremic syndrome 2          germline
# 10270                                       not provided          germline
# 10271                                       not provided          germline
# 10272                                       not provided          germline
# 10273                                       not provided          germline
#
#       OriginSimple Assembly ChromosomeAccession Chromosome      Start  \
# 0         germline   GRCh37         NC_000021.8         21   44483098
# 1         germline   GRCh37         NC_000021.8         21   44486370
# 2         germline   GRCh37         NC_000021.8         21   44483184
# 3         germline   GRCh37         NC_000021.8         21   44486389
# 4         germline   GRCh37         NC_000021.8         21   44479409
# ...            ...      ...                 ...        ...        ...
# 10269     germline   GRCh37        NC_000001.10          1  207940369
# 10270     germline   GRCh37        NC_000001.10          1  207963618
# 10271     germline   GRCh37         NC_000011.9         11   32450128
# 10272     germline   GRCh37        NC_000023.10          X  119603024
# 10273     germline   GRCh37        NC_000023.10          X  153764210
#
#             Stop ReferenceAllele AlternateAllele Cytogenetic  \
# 0       44483098               C               T     21q22.3
# 1       44486370               G               A     21q22.3
# 2       44483184               A               G     21q22.3
# 3       44486389               C               T     21q22.3
# 4       44479409               T               C     21q22.3
# ...          ...             ...             ...         ...
# 10269  207940369               C               T      1q32.2
# 10270  207963618               C               T      1q32.2
# 10271   32450128               G               T       11p13
# 10272  119603024               T               A        Xq24
# 10273  153764210               T               C        Xq28
#
#                                             ReviewStatus  NumberSubmitters  \
# 0      criteria provided, multiple submitters, no con...                 6
# 1                         no assertion criteria provided                 1
# 2      criteria provided, multiple submitters, no con...                 9
# 3                         no assertion criteria provided                 1
# 4                         no assertion criteria provided                 1
# ...                                                  ...               ...
# 10269                     no assertion criteria provided                 1
# 10270                criteria provided, single submitter                 1
# 10271                criteria provided, single submitter                 1
# 10272                criteria provided, single submitter                 1
# 10273                criteria provided, single submitter                 1
#
#               Guidelines TestedInGTR  \
# 0                    NaN           N
# 1                    NaN           N
# 2                    NaN           N
# 3                    NaN           N
# 4                    NaN           N
# ...                  ...         ...
# 10269                NaN           N
# 10270                NaN           N
# 10271  ACMG2013,ACMG2016           N
# 10272                NaN           N
# 10273                NaN           N
#
#                                                 OtherIDs  SubmitterCategories  \
# 0      HGMD:CM930082,OMIM Allelic Variant:613381.0001...                    3
# 1      OMIM Allelic Variant:613381.0002,UniProtKB (pr...                    1
# 2      HGMD:CM920136,OMIM Allelic Variant:613381.0004...                    3
# 3      OMIM Allelic Variant:613381.0005,UniProtKB (pr...                    1
# 4      OMIM Allelic Variant:613381.0007,UniProtKB (pr...                    1
# ...                                                  ...                  ...
# 10269                                                  -                    2
# 10270                                                  -                    2
# 10271                                                  -                    2
# 10272                                                  -                    2
# 10273                                                  -                    2
#
#          From   Entry  Reviewed   Entry Name  \
# 0      P35520  P35520  reviewed    CBS_HUMAN
# 1      P35520  P35520  reviewed    CBS_HUMAN
# 2      P35520  P35520  reviewed    CBS_HUMAN
# 3      P35520  P35520  reviewed    CBS_HUMAN
# 4      P35520  P35520  reviewed    CBS_HUMAN
# ...       ...     ...       ...          ...
# 10269  P15529  P15529  reviewed    MCP_HUMAN
# 10270  P15529  P15529  reviewed    MCP_HUMAN
# 10271  P19544  P19544  reviewed    WT1_HUMAN
# 10272  P13473  P13473  reviewed  LAMP2_HUMAN
# 10273  P11413  P11413  reviewed   G6PD_HUMAN
#
#                                            Protein names      Gene Names  \
# 0      Cystathionine beta-synthase (EC 4.2.1.22) (Bet...             CBS
# 1      Cystathionine beta-synthase (EC 4.2.1.22) (Bet...             CBS
# 2      Cystathionine beta-synthase (EC 4.2.1.22) (Bet...             CBS
# 3      Cystathionine beta-synthase (EC 4.2.1.22) (Bet...             CBS
# 4      Cystathionine beta-synthase (EC 4.2.1.22) (Bet...             CBS
# ...                                                  ...             ...
# 10269  Membrane cofactor protein (TLX) (Trophoblast l...  CD46 MCP MIC10
# 10270  Membrane cofactor protein (TLX) (Trophoblast l...  CD46 MCP MIC10
# 10271                         Wilms tumor protein (WT33)             WT1
# 10272  Lysosome-associated membrane glycoprotein 2 (L...           LAMP2
# 10273  Glucose-6-phosphate 1-dehydrogenase (G6PD) (EC...            G6PD
#
#                                                   RefSeq  \
# 0      NP_000062.1 [P35520-1];NP_001171479.1 [P35520-...
# 1      NP_000062.1 [P35520-1];NP_001171479.1 [P35520-...
# 2      NP_000062.1 [P35520-1];NP_001171479.1 [P35520-...
# 3      NP_000062.1 [P35520-1];NP_001171479.1 [P35520-...
# 4      NP_000062.1 [P35520-1];NP_001171479.1 [P35520-...
# ...                                                  ...
# 10269  NP_002380.3 [P15529-1];NP_722548.1 [P15529-3];...
# 10270  NP_002380.3 [P15529-1];NP_722548.1 [P15529-3];...
# 10271  NP_000369.3;NP_001185480.1 [P19544-6];NP_00118...
# 10272  NP_001116078.1 [P13473-3];NP_002285.1 [P13473-...
# 10273  NP_000393.4 [P11413-3];NP_001035810.1 [P11413-1];
#
#                          Alternative products (isoforms) canonical isoforms  \
# 0      ALTERNATIVE PRODUCTS:  Event=Alternative splic...           P35520-1
# 1      ALTERNATIVE PRODUCTS:  Event=Alternative splic...           P35520-1
# 2      ALTERNATIVE PRODUCTS:  Event=Alternative splic...           P35520-1
# 3      ALTERNATIVE PRODUCTS:  Event=Alternative splic...           P35520-1
# 4      ALTERNATIVE PRODUCTS:  Event=Alternative splic...           P35520-1
# ...                                                  ...                ...
# 10269  ALTERNATIVE PRODUCTS:  Event=Alternative splic...           P15529-1
# 10270  ALTERNATIVE PRODUCTS:  Event=Alternative splic...           P15529-1
# 10271  ALTERNATIVE PRODUCTS:  Event=Alternative splic...           P19544-1
# 10272  ALTERNATIVE PRODUCTS:  Event=Alternative splic...           P13473-1
# 10273  ALTERNATIVE PRODUCTS:  Event=Alternative splic...           P11413-1
#
#       all_canonical_refseq             RNA         Protein
# 0              NP_000062.1     NM_000071.2     NP_000062.1
# 1              NP_000062.1     NM_000071.2     NP_000062.1
# 2              NP_000062.1     NM_000071.2     NP_000062.1
# 3              NP_000062.1     NM_000071.2     NP_000062.1
# 4              NP_000062.1     NM_000071.2     NP_000062.1
# ...                    ...             ...             ...
# 10269          NP_002380.3     NM_002389.4     NP_002380.3
# 10270          NP_002380.3     NM_002389.4     NP_002380.3
# 10271       NP_001185480.1  NM_001198551.1  NP_001185480.1
# 10272          NP_054701.1     NM_013995.2     NP_054701.1
# 10273       NP_001035810.1  NM_001042351.2  NP_001035810.1
#
# [10274 rows x 43 columns]

# %%
print(len(explode(clinvar_on_canonical, column="Gene Names", sep=";")["Gene Names"].unique()))
# Out:
# 370
